# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
font_path = 'C:/Users/daye/Downloads/NanumGothic.ttf'
wordcloud = WordCloud(font_path = font_path, width = 800, height = 800)

# %%
#파일명
file_add_list = ['C:/Users/daye/practice/review/review_지점명제거/brooklyn_review.txt', 'C:/Users/daye/practice/review/review_지점명제거/downtowner_review.txt',
                 'C:/Users/daye/practice/review/review_지점명제거/lotte_review_v2.txt', 'C:/Users/daye/practice/review/review_지점명제거/mc_review.txt', 'C:/Users/daye/practice/review/review_지점명제거/mom_review.txt', 'C:/Users/daye/practice/review/review_지점명제거/shake_review.txt']

# %%
stopwords = ['너무', '더', '좀', '다', '안', '그냥', '것', '잘', '내']

# %%
wordcloud = WordCloud(font_path='C:/Users/daye/Downloads/NanumGothic.ttf', background_color='white', stopwords = stopwords).generate(text)

# %%
#brooklyn
text=open(file_add_list[0]).read()
wordcloud = wordcloud.generate(text)
fig = plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('wordcloud_brooklyn.png')

# %%
#downtowner
text=open(file_add_list[1]).read()
wordcloud = wordcloud.generate(text)
fig = plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('wordcloud_downtowner.png')

# %%
#lotteria
text=open(file_add_list[2]).read()
wordcloud = wordcloud.generate(text)
fig = plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('wordcloud_lotteria.png')

# %%
#mcdonalds
text=open(file_add_list[3]).read()
wordcloud = wordcloud.generate(text)
fig = plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('wordcloud_mc.png')

# %%
#momstouch
text=open(file_add_list[4]).read()
wordcloud = wordcloud.generate(text)
fig = plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('wordcloud_momstouch.png')

# %%
#shakeshack
text=open(file_add_list[5]).read()
wordcloud = wordcloud.generate(text)
fig = plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('wordcloud_shake.png')
